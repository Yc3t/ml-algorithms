# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
cmap = ListedColormap(['#FF0000', '#00FF00','#0000FF'])

# %%
iris = datasets.load_iris()
X,y = iris.data, iris.target

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state=1234)

y_train[1:3]
# Out:
# array([2, 0])

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(X[:,0], X[:,1], c=y, cmap=cmap, edgecolor='k', s=20)
plt.xlabel('Sepal length')
plt.ylabel('Sepal Width')

# Add a legend with class names
class_names = iris.target_names
legend_elements = [plt.Line2D([0], [0], marker='o', color='w', label=class_names[i], 
                   markerfacecolor=cmap(i), markersize=10) for i in range(len(class_names))]
plt.legend(handles=legend_elements, title="Classes")
plt.show()
